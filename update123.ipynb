# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import gzip
import numpy as np

# %%
df1 = pd.read_csv('zippedData/bom.movie_gross.csv.gz')

# %%
df1.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
df2 = pd.read_csv('zippedData/imdb.name.basics.csv.gz')

# %%
df2.head()
# Out:
#       nconst       primary_name  birth_year  death_year  \
# 0  nm0061671  Mary Ellen Bauder         NaN         NaN
# 1  nm0061865       Joseph Bauer         NaN         NaN
# 2  nm0062070         Bruce Baum         NaN         NaN
# 3  nm0062195       Axel Baumann         NaN         NaN
# 4  nm0062798        Pete Baxter         NaN         NaN
#
#                                  primary_profession  \
# 0         miscellaneous,production_manager,producer
# 1        composer,music_department,sound_department
# 2                        miscellaneous,actor,writer
# 3  camera_department,cinematographer,art_department
# 4  production_designer,art_department,set_decorator
#
#                           known_for_titles
# 0  tt0837562,tt2398241,tt0844471,tt0118553
# 1  tt0896534,tt6791238,tt0287072,tt1682940
# 2  tt1470654,tt0363631,tt0104030,tt0102898
# 3  tt0114371,tt2004304,tt1618448,tt1224387
# 4  tt0452644,tt0452692,tt3458030,tt2178256

# %%
df3 = pd.read_csv('zippedData/imdb.title.akas.csv.gz')

# %%
df3.head()
# Out:
#       tconst  ordering                                    title region  \
# 0  tt0369610        10                            Джурасик свят     BG
# 1  tt0369610        11                        Jurashikku warudo     JP
# 2  tt0369610        12  Jurassic World: O Mundo dos Dinossauros     BR
# 3  tt0369610        13                  O Mundo dos Dinossauros     BR
# 4  tt0369610        14                           Jurassic World     FR
#
#   language        types   attributes  is_original_title
# 0       bg          NaN          NaN                0.0
# 1      NaN  imdbDisplay          NaN                0.0
# 2      NaN  imdbDisplay          NaN                0.0
# 3      NaN          NaN  short title                0.0
# 4      NaN  imdbDisplay          NaN                0.0

# %%
df4 = pd.read_csv('zippedData/imdb.title.basics.csv.gz')

# %%
df4.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
df5 = pd.read_csv('zippedData/imdb.title.crew.csv.gz')

# %%
df5.head()
# Out:
#       tconst                      directors              writers
# 0  tt0285252                      nm0899854            nm0899854
# 1  tt0438973                            NaN  nm0175726,nm1802864
# 2  tt0462036                      nm1940585            nm1940585
# 3  tt0835418                      nm0151540  nm0310087,nm0841532
# 4  tt0878654  nm0089502,nm2291498,nm2292011            nm0284943

# %%
df6 = pd.read_csv('zippedData/imdb.title.principals.csv.gz')

# %%
df6.head()
# Out:
#       tconst  ordering     nconst  category       job        characters
# 0  tt0111414         1  nm0246005     actor       NaN       ["The Man"]
# 1  tt0111414         2  nm0398271  director       NaN               NaN
# 2  tt0111414         3  nm3739909  producer  producer               NaN
# 3  tt0323808        10  nm0059247    editor       NaN               NaN
# 4  tt0323808         1  nm3579312   actress       NaN  ["Beth Boothby"]

# %%
df7 = pd.read_csv('zippedData/imdb.title.ratings.csv.gz')

# %%
df7.head()
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
df8 = pd.read_csv('zippedData/rt.movie_info.tsv.gz', sep='\t')
df8 = df8.set_index('id')
df8 = df8.sort_values(by='box_office', ascending=False)

# %%
df8.head()
# Out:
#                                                synopsis rating  \
# id
# 23    A fictional film set in the alluring world of ...      R
# 1944  In the 3D action-comedy The Green Hornet, Brit...  PG-13
# 274   Natalie Portman stars in this western concerni...      R
# 1890  A misplaced sausage and his savory friends emb...      R
# 1711  Directed by Garry Marshall, The Princess Diari...      G
#
#                                                   genre  \
# id
# 23                                                Drama
# 1944  Action and Adventure|Comedy|Science Fiction an...
# 274                  Action and Adventure|Drama|Western
# 1890                                   Animation|Comedy
# 1711                             Comedy|Kids and Family
#
#                         director  \
# id
# 23                           NaN
# 1944               Michel Gondry
# 274                          NaN
# 1890  Conrad Vernon|Greg Tiernan
# 1711              Garry Marshall
#
# ...

# %%
df9 = pd.read_csv('zippedData/rt.reviews.tsv.gz', sep='\t', encoding='windows-1254')
df9 = df9.set_index('id')

# %%
df9.head()
# Out:
#                                                review rating   fresh  \
# id
# 3   A distinctly gallows take on contemporary fina...    3/5   fresh
# 3   It's an allegory in search of a meaning that n...    NaN  rotten
# 3   ... life lived in a bubble in financial dealin...    NaN   fresh
# 3   Continuing along a line introduced in last yea...    NaN   fresh
# 3              ... a perverse twist on neorealism...     NaN   fresh
#
#             critic  top_critic         publisher               date
# id
# 3       PJ Nabarro           0   Patrick Nabarro  November 10, 2018
# 3   Annalee Newitz           0           io9.com       May 23, 2018
# 3     Sean Axmaker           0  Stream on Demand    January 4, 2018
# 3    Daniel Kasman           0              MUBI  November 16, 2017
# 3              NaN           0      Cinema Scope   October 12, 2017

# %%
df10 = pd.read_csv('zippedData/tmdb.movies.csv.gz')
df10 = df10.set_index(['Unnamed: 0'])

# %%
df10.head()
# Out:
#                       genre_ids     id original_language  \
# Unnamed: 0
# 0               [12, 14, 10751]  12444                en
# 1           [14, 12, 16, 10751]  10191                en
# 2                 [12, 28, 878]  10138                en
# 3               [16, 35, 10751]    862                en
# 4                 [28, 878, 12]  27205                en
#
#                                           original_title  popularity  \
# Unnamed: 0
# 0           Harry Potter and the Deathly Hallows: Part 1      33.533
# 1                               How to Train Your Dragon      28.734
# 2                                             Iron Man 2      28.515
# 3                                              Toy Story      28.005
# 4                                              Inception      27.920
#
#            release_date                                         title  \
# Unnamed: 0
# 0            2010-11-19  Harry Potter and the Deathly Hallows: Part 1
# ...

# %%
df11 = pd.read_csv('zippedData/tn.movie_budgets.csv.gz')
#df11 = df11.set_index('id')
df11['worldwide_gross'] = df11['worldwide_gross'].str[1:]
df11['worldwide_gross'] = df11['worldwide_gross'].str.replace(',', '').astype(np.int64)
df11['domestic_gross'] = df11['domestic_gross'].str[1:]
df11['domestic_gross'] = df11['domestic_gross'].str.replace(',', '').astype(np.int64)
df11['production_budget'] = df11['production_budget'].str[1:]
df11['production_budget'] = df11['production_budget'].str.replace(',', '').astype(np.int64)
df11.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget  domestic_gross  worldwide_gross
# 0          425000000       760507625       2776345279
# 1          410600000       241063875       1045663875
# 2          350000000        42762350        149762350
# 3          330600000       459005868       1403013963
# 4          317000000       620181382       1316721747

# %%
df11.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget  domestic_gross  worldwide_gross
# 0          425000000       760507625       2776345279
# 1          410600000       241063875       1045663875
# 2          350000000        42762350        149762350
# 3          330600000       459005868       1403013963
# 4          317000000       620181382       1316721747

# %%
print('DF1:', df1.columns, '\n')
print('DF3: ', df3.columns, '\n')
print('DF4: ', df4.columns, '\n')
print('DF5: ', df5.columns, '\n')
print('DF8: ', df8.columns, '\n')
print('DF9: ', df9.columns, '\n')
print('DF10: ', df10.columns, '\n')
print('DF11: ', df11.columns, '\n')
# Out:
# DF1: Index(['title', 'studio', 'domestic_gross', 'foreign_gross', 'year'], dtype='object')
#
# DF3:  Index(['tconst', 'ordering', 'title', 'region', 'language', 'types',
#        'attributes', 'is_original_title'],
#       dtype='object')
#
# DF4:  Index(['tconst', 'primary_title', 'original_title', 'start_year',
#        'runtime_minutes', 'genres'],
#       dtype='object')
#
# DF5:  Index(['tconst', 'directors', 'writers'], dtype='object')
#
# DF8:  Index(['synopsis', 'rating', 'genre', 'director', 'writer', 'theater_date',
#        'dvd_date', 'currency', 'box_office', 'runtime', 'studio'],
#       dtype='object')
#
# DF9:  Index(['review', 'rating', 'fresh', 'critic', 'top_critic', 'publisher',
#        'date'],
#       dtype='object')
#
# DF10:  Index(['genre_ids', 'id', 'original_language', 'original_title', 'popularity',
#        'release_date', 'title', 'vote_average', 'vote_count'],
#       dtype='object')
#
# ...

# %%
df3 = df3.rename(columns = {'title_id':'tconst'})
BigFrame = pd.concat([df1, df3, df4, df7, df8, df9, df10, df11])
BigFrame.keys()
# Out:
# Index(['title', 'studio', 'domestic_gross', 'foreign_gross', 'year', 'tconst',
#        'ordering', 'region', 'language', 'types', 'attributes',
#        'is_original_title', 'primary_title', 'original_title', 'start_year',
#        'runtime_minutes', 'genres', 'averagerating', 'numvotes', 'synopsis',
#        'rating', 'genre', 'director', 'writer', 'theater_date', 'dvd_date',
#        'currency', 'box_office', 'runtime', 'review', 'fresh', 'critic',
#        'top_critic', 'publisher', 'date', 'genre_ids', 'id',
#        'original_language', 'popularity', 'release_date', 'vote_average',
#        'vote_count', 'movie', 'production_budget', 'worldwide_gross'],
#       dtype='object')

# %%
d = {'title': 'first', 'movie': 'first', 'domestic_gross': 'sum', 'foreign_gross': 'sum', 'worldwide_gross': 'sum', 'primary_title': 'first', 'original_title': 'first', 'production_budget': 'first', 'region': 'first', 'genres': 'first', 'runtime_minutes': 'sum'}
NewFrame = BigFrame.groupby(BigFrame['movie']).aggregate(d)
NewFrame
# Out:
#                             title                       movie  domestic_gross  \
# movie
# #Horror                       NaN                     #Horror             0.0
# (500) Days of Summer          NaN        (500) Days of Summer      32425665.0
# 10 Cloverfield Lane           NaN         10 Cloverfield Lane      72082999.0
# 10 Days in a Madhouse         NaN       10 Days in a Madhouse         14616.0
# 10 Things I Hate About You    NaN  10 Things I Hate About You      38177966.0
# ...                           ...                         ...             ...
# mother!                       NaN                     mother!      17800004.0
# xXx                           NaN                         xXx     141930000.0
# xXx: Return of Xander Cage    NaN  xXx: Return of Xander Cage      44898413.0
# Ã l\'intÃ©rieur               NaN             Ã l\'intÃ©rieur             0.0
# é·æ±ä¸è (CJ7)            NaN          é·æ±ä¸è (CJ7)        206678.0
#
# ...

# %%
df1drop = df1.dropna()
df2drop = df2.dropna()
df3drop = df3.dropna()
df4drop = df4.dropna()
df5drop = df5.dropna()
df6drop = df6.dropna()
df7drop = df7.dropna()
df8drop = df8.dropna()
df9drop = df9.dropna()
df10drop = df10.dropna()
df11drop = df11.dropna()

# %%
df11.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget  domestic_gross  worldwide_gross
# 0          425000000       760507625       2776345279
# 1          410600000       241063875       1045663875
# 2          350000000        42762350        149762350
# 3          330600000       459005868       1403013963
# 4          317000000       620181382       1316721747

# %%
df11.plot.scatter(x = 'production_budget', y = 'domestic_gross');

# %%
df11.plot.scatter(x = 'production_budget', y = 'worldwide_gross');

# %%
df11.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   int64
#  4   domestic_gross     5782 non-null   int64
#  5   worldwide_gross    5782 non-null   int64
# dtypes: int64(4), object(2)
# memory usage: 271.2+ KB

# %%
df11.describe()
# Out:
#                 id  production_budget  domestic_gross  worldwide_gross
# count  5782.000000       5.782000e+03    5.782000e+03     5.782000e+03
# mean     50.372363       3.158776e+07    4.187333e+07     9.148746e+07
# std      28.821076       4.181208e+07    6.824060e+07     1.747200e+08
# min       1.000000       1.100000e+03    0.000000e+00     0.000000e+00
# 25%      25.000000       5.000000e+06    1.429534e+06     4.125415e+06
# 50%      50.000000       1.700000e+07    1.722594e+07     2.798445e+07
# 75%      75.000000       4.000000e+07    5.234866e+07     9.764584e+07
# max     100.000000       4.250000e+08    9.366622e+08     2.776345e+09

# %%
#budget
prod_mean = df11['production_budget'].mean()
prod_median = df11['production_budget'].median()
print(f'Production Budget Mean: {prod_mean}')
print(f'Production Budget Median: {prod_median}')
#domestic gross
domestic_mean = df11['domestic_gross'].mean()
domestic_median = df11['domestic_gross'].median()
print(f'Domestic Gross Mean: {domestic_mean}')
print(f'Domestic Gross Median: {domestic_median}')
#worldwide gross
ww_mean = df11['worldwide_gross'].mean()
ww_median = df11['worldwide_gross'].median()
print(f'Worldwide Gross Mean: {ww_mean}')
print(f'Worldwide Gross Median: {ww_median}')
# Out:
# Production Budget Mean: 31587757.0965064
# Production Budget Median: 17000000.0
# Domestic Gross Mean: 41873326.867001034
# Domestic Gross Median: 17225945.0
# Worldwide Gross Mean: 91487460.90643376
# Worldwide Gross Median: 27984448.5

# %%
#k value (correlation)
print(df11.corr())
# Out:
#                          id  production_budget  domestic_gross  \
# id                 1.000000          -0.035278        0.008255
# production_budget -0.035278           1.000000        0.685682
# domestic_gross     0.008255           0.685682        1.000000
# worldwide_gross   -0.009422           0.748306        0.938853
#
#                    worldwide_gross
# id                       -0.009422
# production_budget         0.748306
# domestic_gross            0.938853
# worldwide_gross           1.000000

# %%
print("The median production budget was $17,000,000 while the mean production budget was ~$31,587,757\n
This is because some films have much higher budgets compared to the average\n
Production budget and world wide gross have a r value of 0.748\n
Production budget and domestic gross have a r value of 0.686\n
These indicate a strong positive correlation between budget and gross.")
# Out:
#   File "<ipython-input-101-80cf7630d6fd>", line 1
#     print("The median production budget was $17,000,000 while the mean production budget was ~$31,587,757\n
#                                                                                                            ^
# SyntaxError: EOL while scanning string literal
